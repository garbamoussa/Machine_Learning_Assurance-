# %%
# %ls
# Out:
#   GRADIENT_BOOSTING_IN_PRACTICE.pdf
# 40 Python Interview and Answer_1556434162.pdf
# API_11_DS2_en_csv_v2_42980/
# API_NER_DS2_en_excel_v2_42313.xls
# A_B Testing.ipynb
# A_new_version_is_out_now__1569550401.pdf
# ActionSocialeFragilité_revu_VLB.xlsx
# Agriculture_Data.ipynb
# Algo/
# Algorithms_Note_for_professionals_1566716738.pdf
# Assessment_of_Feature_Selection_and_Clas.pdf
# Automated_Feature_Engineering_for_Predictive_Modeling.pdf
# Awesome_Visualization_Techniques_1567914151.pdf
# Bank_African.html
# Bank_Data.ipynb
# Bayesian Inference, Markov Chain Monte Carlo and Metropolis Hastings.ipynb
# Best_Practice_for_ML_Engineering_1569180056.pdf
# Big_Data_Case_Study_Collection_1568200517.pdf
# Book/
# Book.pdf
# CG71APA.csv
# CG71AideHabitat19922009.csv
# CG71BailleursSociaux.csv
# Chapter-10---Normal-Crime_2015_Data-Mining-and-Predictive-Analysis.pdf*
# Chapter-16---Future-Trends_2015_Data-Mining-and-Predictive-Analysis.pdf*
# ...

# %%
import pandas as pd 
import numpy as np

# %%
#data_1 = pd.read_csv('logements-subventionnes-dans-les-projets-de-renovation-urbaine.csv')

# %%
data_1.head()
# Out:
#   ANNEE;CODE_INSEE;COMMUNE;PROJET_RENOVATION_URBAINE;MAITRE_D'OUVRAGE;TYPE_OPERATION;NB_LOGEMENTS
# 0  2012;92004;ASNIERES SUR SEINE;LES HAUTS D'ASNI...
# 1  2010;92024;CLICHY;ENTREE DE VILLE - VICTOR HUG...
# 2  2009;92007;BAGNEUX;QUARTIER INTERCOMMUNAL DES ...
# 3  2012;92078;VILLENEUVE LA GARENNE;LES QUARTIERS...
# 4  2012;92025;COLOMBES;PETIT COLOMBES -QUARTIER D...

# %%
data_1.columns
# Out:
# Index(['ANNEE;CODE_INSEE;COMMUNE;PROJET_RENOVATION_URBAINE;MAITRE_D'OUVRAGE;TYPE_OPERATION;NB_LOGEMENTS'], dtype='object')
